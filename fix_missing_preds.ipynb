# %%
from huggingface_hub import hf_hub_download
import pandas as pd
import os

# %%
zip_path = hf_hub_download(
    repo_id="lmms-lab/AISG_Challenge",          # e.g., "lmms-lab/AISG_Challenge"
    filename="Benchmark-AllVideos-HQ-Encoded-challenge.zip",                 # exact filename
    repo_type="dataset"                  # since it's a dataset
)
print(f"Downloaded to: {zip_path}")

# %%
import zipfile

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("/workspace/")  # Extract to the current directory
